# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Importing Data
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
housing.data.shape
# Out:
# (20640, 8)

# %%
data = pd.DataFrame(housing.data)
data.columns = housing.feature_names

data.head(10)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6  3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7  3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8  2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9  3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
# 5    -122.25
# 6    -122.25
# 7    -122.25
# 8    -122.26
# 9    -122.25

# %%
# Adding 'Price' (target) column to the data
housing.target.shape
# Out:
# (20640,)

# %%
data['Price'] = housing.target
data.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
data.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         Price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
data.info()
import seaborn as sns
import numpy as np
import sklearn

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
sns.histplot(data['Price'], kde=True, color='blue')
plt.title('Distribution of x')

metrics =['count', 'std', 'skew']

# plt.subplot(1, 2, 2)
# sns.histplot(y, kde=True, color='green')
# plt.title('Distribution of y')

plt.tight_layout()
plt.show()

# Additional statistical summary
print("Statistical Summary of x:")
print("Mean:", np.mean(data['Price']))
print("Standard Deviation:", np.std(data['Price']))
print()

data.agg(metrics)
# print("Statistical Summary of y:")
# print("Mean:", np.mean(y))
# print("Standard Deviation:", np.std(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
# Statistical Summary of x:
# Mean: 2.068558169089147
# Standard Deviation: 1.1539282040412253
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# ...

# %%
import seaborn as sns
data.describe()
data_temp = data[:15000]['Price']
data_temp = data_temp[data_temp<=4.8]
data_temp.agg(metrics)
data_temp.describe()

sns.histplot(data_temp, kde=True, color='blue')
plt.title('Distribution of x')

metrics =['count', 'std', 'skew']

#plt.subplot(1, 2, 2)
#sns.histplot(y, kde=True, color='green')
#plt.title('Distribution of y')

plt.tight_layout()
plt.show()

# %%
data.info()
import seaborn as sns
import numpy as np
import sklearn

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
sns.histplot(data_temp, kde=True, color='blue')
plt.title('Distribution of x')

metrics =['count', 'std', 'skew']

# plt.subplot(1, 2, 2)
# sns.histplot(y, kde=True, color='green')
# plt.title('Distribution of y')

plt.tight_layout()
plt.show()

# Additional statistical summary
print("Statistical Summary of x:")
print("Mean:", np.mean(data_temp))
print("Standard Deviation:", np.std(data_temp))
print()

data.agg(metrics)
# print("Statistical Summary of y:")
# print("Mean:", np.mean(y))
# print("Standard Deviation:", np.std(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
# Statistical Summary of x:
# Mean: 1.8389416762237765
# Standard Deviation: 0.9214981211708655
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# ...

# %%
data.info()
import seaborn as sns
import numpy as np
import sklearn

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
sns.histplot(data['Price'], kde=True, color='blue')
plt.title('Distribution of x')

metrics =['count', 'std', 'skew']

# plt.subplot(1, 2, 2)
# sns.histplot(y, kde=True, color='green')
# plt.title('Distribution of y')

plt.tight_layout()
plt.show()

# Additional statistical summary
print("Statistical Summary of x:")
print("Mean:", np.mean(data['Price']))
print("Standard Deviation:", np.std(data['Price']))
print()

data.agg(metrics)
# print("Statistical Summary of y:")
# print("Mean:", np.mean(y))
# print("Standard Deviation:", np.std(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
# Statistical Summary of x:
# Mean: 2.068558169089147
# Standard Deviation: 1.1539282040412253
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# ...

# %%
# Input Data
x = housing.data

# Output Data
y = housing.target


# splitting data to training and testing dataset.

#from sklearn.cross_validation import train_test_split
#the submodule cross_validation is renamed and deprecated to model_selection
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size =0.3,
													random_state = 0)

print("xtrain shape : ", xtrain.shape)
print("xtest shape : ", xtest.shape)
print("ytrain shape : ", ytrain.shape)
print("ytest shape : ", ytest.shape)
# Out:
# xtrain shape :  (14448, 8)
# xtest shape :  (6192, 8)
# ytrain shape :  (14448,)
# ytest shape :  (6192,)

# %%
# Fitting Multi Linear regression model to training model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(xtrain, ytrain)

# predicting the test set results
y_pred = regressor.predict(xtest)

# %% [markdown]
# **from sklearn.linear_model import LinearRegression**:
#
#  This line imports the LinearRegression class from the linear_model module in the sklearn (scikit-learn) library. LinearRegression is a class that is used to perform linear regression.
#
# **regressor = LinearRegression():**
#
# This line creates an instance of the LinearRegression class. The variable regressor is now an object that represents the linear regression model.
#
# **regressor.fit(xtrain, ytrain)**:
#
# This line fits the linear regression model to the training data. The fit method takes two arguments: xtrain (the features of the training data) and ytrain (the target variable of the training data). The model learns the coefficients for the linear equation that best fits the training data.
#
# **y_pred = regressor.predict(xtest)**:
#
# This line uses the fitted linear regression model to make predictions on the test data. The predict method takes one argument: xtest (the features of the test data). It returns y_pred, which is the model's predictions for the target variable based on the test features.

# %%
# Plotting Scatter graph to show the prediction
# results - 'ytrue' value vs 'y_pred' value
plt.scatter(ytest, y_pred, c = 'green')
plt.xlabel("Price: in $1000's")
plt.ylabel("Predicted value")
plt.title("True value vs predicted value : Linear Regression")
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mse = mean_squared_error(ytest, y_pred)
mae = mean_absolute_error(ytest,y_pred)
print("Mean Square Error : ", mse)
print("Mean Absolute Error : ", mae)
# Out:
# Mean Square Error :  0.5431489670037245
# Mean Absolute Error :  0.5361818140641894
